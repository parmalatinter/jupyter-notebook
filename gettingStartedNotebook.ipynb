# %%
Jupyter Getting Started

# %%
print("Hello notebook")
# Out:
# Hello notebook

# %%
1. Add method

# %%
def caliculate(x):
    y = x +  1
    return y

# %%
2. Use Method

# %%
print(caliculate(1))
# Out:
# 2

# %%
3.Use Library

# %%
import sympy as sym
from sympy.plotting import plot

x, y = sym.symbols("x y")

y = x ** 2 + 2 * x - 3

xRange = (x, -10, 10)
plot(y, xRange)
